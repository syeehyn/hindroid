# %%
import sys
sys.path.append('../src')
import utils
import json
from glob import glob
# %load_ext autoreload
# %autoreload 2

# %%
cfg = json.load(open("../config/data-params.json"))

# %%
# %cd ..
# Out:
# /Users/syeehyn/Desktop/wi20/dsc180a/hindroid

# %%
cfg
# Out:
# {'dir': '../data',
#  'urls': ['https://apkpure.com/real-laser-for-cat-joke-guide/com.jun05.reallaserforcatjokeguide',
#   'https://apkpure.com/sky-invasion-unlimited/com.techninier.sriInt',
#   'https://apkpure.com/%C4%91i%E1%BB%81u-l%E1%BB%87-%C4%91%E1%BA%A3ng/com.huynhducdinh.dieuledang',
#   'https://apkpure.com/venus-interactive-video-player/com.gleemate.venus',
#   'https://apkpure.com/keypos-%ED%83%9C%EB%B8%94%EB%A6%BF%EC%9D%84-pos%EB%A1%9C/kis.arumnet.cloudpos',
#   'https://apkpure.com/santa-claus-christmas-mission-adventure/com.Running.Santa.Christmas.MissionAdventure',
#   'https://apkpure.com/chalkboard-catering/com.chalkboard.catering',
#   'https://apkpure.com/cockroach-smasher/com.synverplay.smasher',
#   'https://apkpure.com/independence-day-pictures/com.doublenine.apps.happy.indian.independence.day.pictures',
#   'https://apkpure.com/simone-simaria-paga-de-solteiro-feliz-musica/com.ChartMusicStudio.SimoneeSimaria',
# ...

# %%
utils.get_data(**cfg)
# Out:
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# distributed.nanny - WARNING - Restarting worker
# ...
# 100%|██████████| 10/10 [06:43<00:00, 58.82s/it]
# 'apk download and decode finished'

# %%
json.load(open('../data/raw/app_map.json'))
# Out:
# {'real-laser-for-cat-joke-guide': {'download': 'failed', 'decode': 'failed'},
#  'sky-invasion-unlimited': {'download': 'failed', 'decode': 'failed'},
#  '%C4%91i%E1%BB%81u-l%E1%BB%87-%C4%91%E1%BA%A3ng': {'download': 'failed',
#   'decode': 'failed'},
#  'venus-interactive-video-player': {'download': 'success', 'decode': 'done'},
#  'keypos-%ED%83%9C%EB%B8%94%EB%A6%BF%EC%9D%84-pos%EB%A1%9C': {'download': 'success',
#   'decode': 'done'},
#  'santa-claus-christmas-mission-adventure': {'download': 'success',
#   'decode': 'done'},
#  'chalkboard-catering': {'download': 'failed', 'decode': 'failed'},
#  'cockroach-smasher': {'download': 'success', 'decode': 'done'},
#  'independence-day-pictures': {'download': 'failed', 'decode': 'failed'},
#  'simone-simaria-paga-de-solteiro-feliz-musica': {'download': 'failed',
#   'decode': 'failed'},
#  'neon-clock-live-wallpaper': {'download': 'failed', 'decode': 'failed'},
#  'ugenr-widget': {'download': 'success', 'decode': 'done'},
# ...

# %%
import pandas as pd
pd.Series(json.load(open('../data/raw/app_map.json'))).apply(lambda x: x['decode']).value_counts()
# Out:
# done      93
# failed    55
# dtype: int64
